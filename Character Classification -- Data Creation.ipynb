# %% [markdown]
# # Create Data for Word Recognition
#
# A simple UI for creating and labeling character classification data

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# Import Widgets
from ipywidgets import Button, Text, HBox, VBox
from IPython.display import display, clear_output

# Timestamp
import time

# For transforming letters encoding (removing accents)
import unicodedata as ud

# Creating folders
import os

# Import custom functions, corresponding to notebooks
from ocr import page, words, charSeg
from ocr.normalization import imageNorm

# Helper functions - ploting and resizing
from ocr.helpers import implt, resize, ratio
# Out:
# Loading Segmantation model:

# %% [markdown]
# ## Variables

# %%
IMG = "N_173v_"

# %% [markdown]
# ## Load Image

# %%
image = cv2.cvtColor(cv2.imread("images/%s.jpg" % IMG), cv2.COLOR_BGR2RGB)
implt(image, None, IMG)

# %%
# Crop image and get bounding boxes
crop = page.detection(image)
from lib import ndl_crop
from lib.ndl_crop import autocrop_image
crop = autocrop_image(crop)
implt(crop, None, 'cropped')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-5b33e24abff1> in <module>()
#       1 # Crop image and get bounding boxes
#       2 crop = page.detection(image)
# ----> 3 from lib import ndl_crop
#       4 from lib.ndl_crop import autocrop_image
#       5 crop = autocrop_image(crop)
#
# ImportError: cannot import name 'ndl_crop'
